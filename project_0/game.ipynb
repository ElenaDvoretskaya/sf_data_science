# %%
import game_v2

# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game
from game_v2 import random_predict

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число за:7 попыток. Это число = 33
# Ваш алгоритм угадывает число за:3 попыток. Это число = 62
# Ваш алгоритм угадывает число за:6 попыток. Это число = 95
# Ваш алгоритм угадывает число за:4 попыток. Это число = 81
# Ваш алгоритм угадывает число за:6 попыток. Это число = 35
# Ваш алгоритм угадывает число за:7 попыток. Это число = 5
# Ваш алгоритм угадывает число за:4 попыток. Это число = 94
# Ваш алгоритм угадывает число за:7 попыток. Это число = 98
# Ваш алгоритм угадывает число за:7 попыток. Это число = 77
# Ваш алгоритм угадывает число за:2 попыток. Это число = 25
# Ваш алгоритм угадывает число за:7 попыток. Это число = 33
# Ваш алгоритм угадывает число за:4 попыток. Это число = 31
# Ваш алгоритм угадывает число за:7 попыток. Это число = 14
# Ваш алгоритм угадывает число за:5 попыток. Это число = 15
# Ваш алгоритм угадывает число за:4 попыток. Это число = 68
# Ваш алгоритм угадывает число за:6 попыток. Это число = 51
# ...
